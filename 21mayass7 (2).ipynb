# %%
Q.1. Create two int type variables, apply addition, subtraction, division and multiplications
and store the results in variables. Then print the data in the following format by calling the
variables:
First variable is __ & second variable is __.
Addition: __ + __ = __
Subtraction: __ - __ = __
Multiplication: __ * __ = __
Division: __ / __ = __


Ans:
# Create variables
first_variable = 10
second_variable = 5

# Perform operations
addition_result = first_variable + second_variable
subtraction_result = first_variable - second_variable
multiplication_result = first_variable * second_variable
division_result = first_variable / second_variable

# Print the results
print("First variable is", first_variable, "& second variable is", second_variable)
print("Addition:", first_variable, "+", second_variable, "=", addition_result)
print("Subtraction:", first_variable, "-", second_variable, "=", subtraction_result)
print("Multiplication:", first_variable, "*", second_variable, "=", multiplication_result)
print("Division:", first_variable, "/", second_variable, "=", division_result)

# %%
Q.2. What is the difference between the following operators:
(i) ‘/’ & ‘//’
(ii) ‘**’ & ‘^’

Ans:

(i) The '/' operator is used for division in Python, and it returns the quotient as a float. For example, 10 / 3 would
 result in 3.33333... The '//' operator, on the other hand, is called the floor division operator. It performs division 
and returns the quotient as an integer, discarding any decimal places. So, 10 // 3 would result in 3, as it gives the whole
 number quotient without the remainder.

Here's an example to illustrate the difference:
# Division (/) example
result1 = 10 / 3
print(result1)  # Output: 3.3333333333333335

# Floor Division (//) example
result2 = 10 // 3
print(result2)  # Output: 3



(ii) The '**' operator in Python is used for exponentiation. It raises the left operand to the power of the right operand. 
For example, 2 ** 3 would result in 8, as 2 raised to the power of 3 is 8.

On the other hand, the '^' symbol is not an exponentiation operator in Python. Instead, it is used as the bitwise XOR operator
 for integer values.

Here's an example to illustrate the usage of the '**' operator for exponentiation:
# Exponentiation (**) example
result1 = 2 ** 3
print(result1)  # Output: 8

# Incorrect usage of '^' symbol
result2 = 2 ^ 3
print(result2)  # Output: 1 (bitwise XOR of 2 and 3)
# Exponentiation (**) example
result1 = 2 ** 3
print(result1)  # Output: 8

# Incorrect usage of '^' symbol
result2 = 2 ^ 3
print(result2)  # Output: 1 (bitwise XOR of 2 and 3)

# %%
Q.3. List the logical operators.
Ans:

The logical operators in Python are:

i.and: The and operator returns True if both operands are True, and False otherwise.

ii.or: The or operator returns True if at least one of the operands is True, and False otherwise.

iii.not: The not operator is a unary operator that negates the truth value of its operand. It returns True if the operand is False, and vice versa.

# %%
Q.4. Explain right shift operator and left shift operator with examples.
Ans:
i.Right Shift (>>):
The right shift operator (>>) shifts the bits of a number towards the right by a specified number of positions. It effectively 
divides the number by 2 raised to the power of the shift amount.
# Right shift (>>) example
number = 16  # Binary: 10000
shift_amount = 2

result = number >> shift_amount
print(result)  # Output: 4 (Binary: 100)


ii.Left Shift (<<):
The left shift operator (<<) shifts the bits of a number towards the left by a specified number of positions. It effectively 
multiplies the number by 2 raised to the power of the shift amount.
# Left shift (<<) example
number = 5  # Binary: 101
shift_amount = 2

result = number << shift_amount
print(result)  # Output: 20 (Binary: 10100)

# %%
Q.5. Create a list containing int type data of length 15. Then write a code to check if 10 is
present in the list or not.

Ans:
# Create a list of integers
my_list = [5, 8, 3, 10, 12, 7, 15, 20, 18, 25, 14, 30, 11, 9, 6]

# Check if 10 is present in the list
if 10 in my_list:
    print("The number 10 is present in the list.")
else:
    print("The number 10 is not present in the list.")
